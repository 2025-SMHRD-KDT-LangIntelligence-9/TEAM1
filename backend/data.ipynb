# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\smhrd\Desktop\backend\data\merged_data_4class.xlsx")
data
# Out:
#           original_text                      corr_text context_type
# 0       이거 오늘까지 무조건 끝내.                오늘까지 완료 부탁드립니다.           업무
# 1        왜 이렇게 하라고 했잖아.          이 방향으로 진행해 주시면 좋겠습니다.           업무
# 2          그냥 시키는 대로 해.             말씀드린 방식으로 진행해 주세요.           업무
# 3     내가 몇 번을 말해야 알아들어?   다시 한번 안내드릴게요, 이 방향으로 부탁드립니다.           업무
# 4           이게 그렇게 어려워?          어려운 부분이 있으시면 말씀해 주세요.           업무
# ...                 ...                            ...          ...
# 1416  동의하기 어려운 부분이 있어요.          이 부분에 대해 다른 의견이 있습니다.         의견충돌
# 1417     그 결정에 문제가 있어요.       그 결정에 대해 다시 논의해볼 수 있을까요?         의견충돌
# 1418        처리가 너무 늦어요.  진행이 조금 늦어지고 있는데 어려운 점이 있으신가요?           업무
# 1419        답장이 너무 늦네요.     회신이 조금 늦어지고 있는데 확인해 주시겠어요?           업무
# 1420           진행이 더뎌요.          진행 속도를 높여주시면 감사하겠습니다.           업무
#
# [1421 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1624 entries, 0 to 1623
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   original_text  1624 non-null   object
#  1   corr_text      1624 non-null   object
#  2   context_type   1624 non-null   object
# dtypes: object(3)
# memory usage: 38.2+ KB

# %%
for context in data['context_type'].unique():
    count = len(data[data['context_type'] == context])
    print(f'{context}: {count}개')
# Out:
# 업무지시: 313개
# 업무보고: 296개
# 의견충돌: 240개
# 피드백: 286개
# 사과: 286개
# 관계: 203개
