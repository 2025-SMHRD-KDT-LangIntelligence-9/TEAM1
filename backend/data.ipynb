# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\smhrd\Desktop\backend\data\데이터파일_정제__1_ (1).xlsx")
data
# Out:
#                                original_text  \
# 0                            이거 오늘까지 무조건 끝내.
# 1                               이렇게 하라고 했잖아.
# 2                               그냥 시키는 대로 해.
# 3                          내가 몇 번을 말해야 알아들어?
# 4                                이게 그렇게 어려워?
# ...                                      ...
# 1655    이 정도 일에 며칠씩 걸리는 건 역량 부족이라고밖에 안 보입니다.
# 1656  집중 좀 하세요. 자리 비우는 시간이 업무 시간보다 긴 것 같습니다.
# 1657  미리미리 준비 안 하니까 항상 막판에 허둥대고 실수가 나오는 겁니다.
# 1658        기한은 협상의 대상이 아니라 반드시 지켜야 할 약속입니다.
# 1659          시간 아까우니까 핵심만 말하세요. 서론이 너무 깁니다.
#
#                                        corr_text context_type
# 0                                오늘까지 완료 부탁드립니다.           업무
# 1                          이 방향으로 진행해 주시면 좋겠습니다.           업무
# 2                             말씀드린 방식으로 진행해 주세요.           업무
# 3                   다시 한번 안내드릴게요, 이 방향으로 부탁드립니다.           업무
# 4                          어려운 부분이 있으시면 말씀해 주세요.           업무
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1660 entries, 0 to 1659
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   original_text  1660 non-null   object
#  1   corr_text      1660 non-null   object
#  2   context_type   1660 non-null   object
# dtypes: object(3)
# memory usage: 39.0+ KB

# %%
for context in data['context_type'].unique():
    count = len(data[data['context_type'] == context])
    print(f'{context}: {count}개')
# Out:
# 업무: 570개
# 의견충돌: 552개
# 피드백: 277개
# 사과: 261개

# %%
# 1. 피드백 컬럼만 추출 (결측치 제거 및 중복 제거 포함)
feedback_data = data['context_type'].dropna().unique()

# 2. DataFrame으로 변환 후 저장 (CSV 예시)
# '타입' 컬럼이 '피드백'인 데이터만 필터링
feedback_rows = data[data['context_type'] == '피드백']

# 파일로 저장 (예: feedback_rows.csv)
feedback_rows.to_csv("filtered_feedback.csv", index=False, encoding='utf-8-sig')

# 또는 텍스트 파일(.txt)로 저장하고 싶을 경우
# with open("feedback_list.txt", "w", encoding="utf-8") as f:
#     f.write("\n".join(feedback_data))
