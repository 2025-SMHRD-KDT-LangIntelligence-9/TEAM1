# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\smhrd\Desktop\backend\data\데이터파일 (5).xlsx")
data
# Out:
#           original_text                     corr_text context_type
# 0       이거 오늘까지 무조건 끝내.               오늘까지 완료 부탁드립니다.           업무
# 1          이렇게 하라고 했잖아.         이 방향으로 진행해 주시면 좋겠습니다.           업무
# 2          그냥 시키는 대로 해.            말씀드린 방식으로 진행해 주세요.           업무
# 3     내가 몇 번을 말해야 알아들어?  다시 한번 안내드릴게요, 이 방향으로 부탁드립니다.           업무
# 4           이게 그렇게 어려워?         어려운 부분이 있으시면 말씀해 주세요.           업무
# ...                 ...                           ...          ...
# 2249          감사하고 설레요.               감사하고 설레는 마음이에요!           일상
# 2250       오늘 진짜 즐거웠어요.             오늘 정말 즐거운 하루였습니다!           일상
# 2251       뭔가 기분이 업됐어요.           오늘 기분이 좋게 업된 것 같아요!           일상
# 2252          마음이 따뜻해요.           오늘 마음이 따뜻해지는 하루였어요.           일상
# 2253       오늘 하루도 감사해요.        오늘 하루도 감사한 마음으로 마무리해요.           일상
#
# [2254 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2254 entries, 0 to 2253
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   original_text  2254 non-null   object
#  1   corr_text      2254 non-null   object
#  2   context_type   2254 non-null   object
# dtypes: object(3)
# memory usage: 53.0+ KB

# %%
for context in data['context_type'].unique():
    count = len(data[data['context_type'] == context])
    print(f'{context}: {count}개')
# Out:
# 업무: 566개
# 의견충돌: 552개
# 피드백: 453개
# 사과: 260개
# 일상: 423개

# %%
# 1. 피드백 컬럼만 추출 (결측치 제거 및 중복 제거 포함)
feedback_data = data['context_type'].dropna().unique()

# 2. DataFrame으로 변환 후 저장 (CSV 예시)
# '타입' 컬럼이 '피드백'인 데이터만 필터링
feedback_rows = data[data['context_type'] == '피드백']

# 파일로 저장 (예: feedback_rows.csv)
feedback_rows.to_csv("filtered_feedback.csv", index=False, encoding='utf-8-sig')

# 또는 텍스트 파일(.txt)로 저장하고 싶을 경우
# with open("feedback_list.txt", "w", encoding="utf-8") as f:
#     f.write("\n".join(feedback_data))
